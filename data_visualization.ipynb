# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\week1_assignment\movie.csv")

# %%
# Display Dataset Information
print("\n       DATASET OVERVIEW      ")
print(df.head())
# Out:
#        DATASET OVERVIEW
#               Movie    Genre  Rating  Year Language  Duration_Minutes  \
# 0         Inception   Sci-Fi     8.8  2010  English               148
# 1      Interstellar   Sci-Fi     8.6  2014  English               169
# 2   The Dark Knight   Action     9.0  2008  English               152
# 3  Avengers Endgame   Action     8.4  2019  English               181
# 4           Titanic  Romance     7.9  1997  English               195
#
#             Director
# 0  Christopher Nolan
# 1  Christopher Nolan
# 2  Christopher Nolan
# 3      Anthony Russo
# 4      James Cameron

# %%
# Genre Distribution

# %%
genre_count = df["Genre"].value_counts()

# %%
plt.figure(figsize=(8,5))

# %%
genre_count.plot(kind="bar")
plt.title("Number of Movies by Genre")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.show()

# %%
# Movies Rating Distribution

# %%
plt.figure(figsize=(8,5))

# %%
plt.hist(df["Rating"], bins=10)
plt.title("Distribution of Movie Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
# Movies Released Per Year

# %%
year_count = df["Year"].value_counts().sort_index()

# %%
plt.figure(figsize=(10,5))

# %%
plt.plot(year_count.index, year_count.values, marker="o")
plt.title("Movies Released Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.show()

# %%
# Genre Share

# %%
plt.figure(figsize=(8,8))

# %%
df["Genre"].value_counts().head(5).plot(
    kind="pie",
    autopct="%1.1f%%"
)
plt.title("Top 5 Genres Share")
plt.ylabel("")
plt.show()

# %%
print("\nVisualization Completed Successfully")
# Out:
# Visualization Completed Successfully
